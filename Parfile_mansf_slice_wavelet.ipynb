# %%
import pyvista as pv

# %% [markdown]
# Running - https://github.com/TOMOFAST/Tomofast-x/blob/master/parfiles/Parfile_mansf_slice_wavelet.txt

# %%
test_model = pv.read(r'J:\tomofastx_test\output\mansf_slice\Paraview\grav_final_model3D_full_lego.vtk')

# %%
test_model
# Out:
# UnstructuredGrid (0x2be31a83460)
#   N Cells:	8192
#   N Points:	65536
#   X Bounds:	8.001e+03, 8.255e+03
#   Y Bounds:	0.000e+00, 1.626e+04
#   Z Bounds:	-2.880e+03, -0.000e+00
#   N Arrays:	1

# %%
test_model.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x2BE31A8CD00>
# [(26543.740095935707, 26543.740095935707, 16975.740095935707),
#  (8128.0, 8128.0, -1440.0),
#  (0.0, 0.0, 1.0)]
